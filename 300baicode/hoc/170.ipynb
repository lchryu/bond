# %% [markdown]
# input stuff

# %%
list_input = input()
something = int(input())

# %% [markdown]
# main

# %%
list_input = list_input[:something] + list_input[something+1:]
print(list_input)

# %% [markdown]
# done.
